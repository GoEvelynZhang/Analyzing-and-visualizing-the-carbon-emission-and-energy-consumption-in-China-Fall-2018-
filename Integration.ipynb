# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raw = ['Raw Coal','Briquettes','Coke','Coke Oven Gas','Other Coking Products','Crude Oil','Kerosene',"Diesel Oil",
       'Fuel Oil','Other Petroleum Products','Heat']
clean = ['Cleaned Coal','Other Gas','Gasoline',"LPG",'Refinery Gas','Natural Gas', 'Electricity', 'Other Energy',
         'Other Washed Coal']

coal_solid=['Raw Coal','Briquettes','Coke','Other Coking Products','Cleaned Coal','Other Washed Coal']# ton, solid
petroleum_liquid=['Crude Oil','Kerosene',"Diesel Oil",'Fuel Oil','Other Petroleum Products','Gasoline',"LPG",'Refinery Gas'] #ton, liquid
gas=['Coke Oven Gas','Natural Gas','Other Gas']#cu.m
secondary_other=['Heat','Electricity','Other Energy']

a = {"West":["Chongqing","Sichuan","Guizhou","Yunnan","Shaanxi","Gansu","Qinghai","Ningxia","Xinjiang"],\
     "Middle":["Henan","Inner mongolia","Jilin","Heilongjiang","Jiangxi","Hubei","Hunan","Shanxi","Anhui"],\
     "East":["Hainan","Guangxi","Guangdong","Shandong","Tianjin","Beijing","Hebei","Liaoning","Shanghai","Jiangsu","Zhejiang","Fujian"]}

# %% [markdown]
# ### China's energy consumption trend - national level

# %%
df2015=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2015')
con2015=df2015.loc['Total Final Consumption',:]
con2015
# Out:
# Raw Coal                    94027.5
# Cleaned Coal                 5854.3
# Other Washed Coal           10408.4
# Briquettes                   1905.2
# Coke                          43775
# Coke Oven Gas                 588.5
# Other Gas                    6032.5
# Other Coking Products        1077.2
# Crude Oil                     782.7
# Gasoline                    11367.9
# Kerosene                     2663.7
# Diesel Oil                  17280.4
# Fuel Oil                     2123.7
# LPG                          3578.6
# Refinery Gas                   1576
# Other Petroleum Products    13072.6
# Natural Gas                  1209.7
# Heat                         396779
# Electricity                 55032.1
# Other Energy                 5526.8
# Name: Total Final Consumption, dtype: object

# %%
df2014=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2014')
con2014=df2014.loc['Total Final Consumption',:]
df2013=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2013')
con2013=df2013.loc['Total Final Consumption',:]
df2012=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2012')
con2012=df2012.loc['Total Final Consumption',:]
df2011=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2011')
con2011=df2011.loc['Total Final Consumption',:]
df2010=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2010')
con2010=df2010.loc['Total Final Consumption',:]
df2009=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2009')
con2009=df2009.loc['Total Final Consumption',:]
df2008=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2008')
con2008=df2008.loc['Total Final Consumption',:]
df2007=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2007')
con2007=df2007.loc['Total Final Consumption',:]
df2006=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2006')
con2006=df2006.loc['Total Final Consumption',:]
df2005=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2005')
con2005=df2005.loc['Total Final Consumption',:]
df2004=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2004')
con2004=df2004.loc['Total Final Consumption',:]
df2003=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2003')
con2003=df2003.loc['Total Final Consumption',:]
df2002=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2002')
con2002=df2002.loc['Total Final Consumption',:]
df2001=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',sheet_name='2001')
con2001=df2001.loc['Total Final Consumption',:]
dic={}
dic={'2001':con2001,'2002':con2002,'2003':con2003,'2004':con2004,'2005':con2005,
     '2006':con2006,'2007':con2007,'2008':con2008,'2009':con2009,'2010':con2010,
     '2011':con2011,'2012':con2012,'2013':con2013,'2014':con2014,'2015':con2015}
df=pd.DataFrame(dic)
df
# Out:
#                              2001     2002     2003     2004     2005  \
# Raw Coal                  46683.6  48642.6  56775.7  68322.8  76467.8
# Cleaned Coal               1188.1    932.4   1634.2   2622.7   2867.4
# Other Washed Coal          4113.8   4165.7   4349.5   5530.8   5874.3
# Briquettes                  859.1    915.7   1104.1   1133.3   1176.1
# Coke                      11777.8  12665.8  15748.6  17872.7  24877.9
# Coke Oven Gas               236.6    245.4    277.8    312.5    454.1
# Other Gas                  2030.4     1435   1447.2   1707.5   2168.1
# Other Coking Products       230.8      250      304    394.5    389.8
# Crude Oil                   654.1    684.3    812.2    844.9    850.4
# Gasoline                   3596.9   3803.6   4192.9   4695.3   4854.1
# Kerosene                    890.3    919.2      952   1060.9   1076.8
# Diesel Oil                 6917.6   7560.9   8498.2  10072.9  10889.4
# ...

# %%
dft=df.T

# %%
#drop energy type in secondary_other 
df.loc[df.index.isin(secondary_other),:]
# Out:
#                 2001     2002     2003     2004     2005     2006     2007  \
# Heat          151407   162180   175278   190322   226259   243836   255427
# Electricity    13690  15296.8  17770.9  20550.8  23233.9  26729.1  30650.1
# Other Energy    1763   2040.2     2313   2633.2   2935.7   3213.9   3467.9
#
#                  2008     2009     2010     2011     2012     2013     2014  \
# Heat           254588   263573   298818   318574   342687   360409   373319
# Electricity   32403.5  34773.9  39366.3  44300.2  46866.5  51062.7  53283.8
# Other Energy   3678.3   3966.4   4410.1   4720.3   5080.7     5536   5736.9
#
#                  2015
# Heat           396779
# Electricity   55032.1
# Other Energy   5526.8

# %%
dft=dft.drop(dft.loc[:,dft.columns.isin(secondary_other)],axis=1)

# %%
dft
# Out:
#      Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke  \
# 2001  46683.6       1188.1            4113.8      859.1  11777.8
# 2002  48642.6        932.4            4165.7      915.7  12665.8
# 2003  56775.7       1634.2            4349.5     1104.1  15748.6
# 2004  68322.8       2622.7            5530.8     1133.3  17872.7
# 2005  76467.8       2867.4            5874.3     1176.1  24877.9
# 2006  81344.7       3162.8            6187.6       1456  28069.9
# 2007  87347.6       3563.5            7022.4       1753  30900.1
# 2008  90391.2       4183.6            7561.5       1814  31932.6
# 2009  96209.9         4546            8742.2     1972.3  36189.7
# 2010  98766.3       4702.8            9331.3     2025.3  38574.6
# 2011   104186       5099.4              9492     1869.4  41954.3
# 2012   101592       5009.6           10441.6     1913.9  44738.5
# 2013   102942       5027.4              9633     1888.8  45817.5
# ...

# %%
dft_sorted=dft.sort_values(by=['2015'],axis=1,ascending=False)
dft_sorted
# Out:
#      Raw Coal     Coke Diesel Oil Other Petroleum Products Gasoline  \
# 2001  46683.6  11777.8     6917.6                   3691.3   3596.9
# 2002  48642.6  12665.8     7560.9                   4331.5   3803.6
# 2003  56775.7  15748.6     8498.2                     4857   4192.9
# 2004  68322.8  17872.7    10072.9                   6095.8   4695.3
# 2005  76467.8  24877.9    10889.4                   6002.1   4854.1
# 2006  81344.7  28069.9    12003.8                   6530.5   5417.7
# 2007  87347.6  30900.1    12420.2                   7203.7     5519
# 2008  90391.2  31932.6    13475.5                   7054.8   6145.4
# 2009  96209.9  36189.7    13494.8                   8475.5   6172.6
# 2010  98766.3  38574.6    14655.2                  11296.1   6956.1
# 2011   104186  41954.3    15593.5                    11748   7595.8
# 2012   101592  44738.5    16900.7                  11824.3   8165.8
# 2013   102942  45817.5    17106.8                    12100   9366.2
# ...

# %%
#top 5 most consumed energy type
fig, ax = plt.subplots()
dft_sorted.iloc[:,:5].plot(ax=ax,figsize=(12,5))  
ax.set_title('Trend for Different Types of Energy 2001-2015',fontsize=20)
plt.rcParams['figure.dpi'] = 200
plt.show()

# %%
#types in coal_solid 
fig, ax = plt.subplots()
dft_sorted.loc[:,dft_sorted.columns.isin(coal_solid)].plot(ax=ax,figsize=(10,5))  
ax.set_title('Trend for Differnt Types of Energy in Coal_solid',fontsize=20)
plt.rcParams['figure.dpi'] = 200
plt.show()

# %%
#types in petroleum_liquid
fig, ax = plt.subplots()
dft_sorted.loc[:,dft_sorted.columns.isin(petroleum_liquid)].plot(ax=ax,figsize=(10,5))  
ax.set_title('Trend for Differnt Types of Energy in Petroleum_liquid',fontsize=20)
ax.legend(loc='upper left')
plt.rcParams['figure.dpi'] = 200
plt.show()

# %%
#types in gas
fig, ax = plt.subplots()
dft_sorted.loc[:,dft_sorted.columns.isin(gas)].plot(ax=ax,figsize=(10,5))  
ax.set_title('Trend for Differnt Types of Energy in Gas',fontsize=20)
plt.rcParams['figure.dpi'] = 200
plt.show()

# %% [markdown]
# # CO2 per capita in province groups

# %%
# improt population data 
population=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National population by province.xls')
population=population.drop(2000,axis=1)
population=population.T

# %%
population_num=population*10000
population_national=population_num.T.sum()

fig,ax = plt.subplots()
population_national.plot(ax=ax,figsize=(7,5))
ax.set_title('Change of Population in China',fontsize=20)
# Out:
# Text(0.5,1,'Change of Population in China')

# %%
# import provincial CO2 imission data 2001-2015
CO2=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/Province sectoral CO2 emissions 2001-2015.xlsx')
CO2=CO2.T
CO2
# Out:
#       Beijing  Tianjin  Hebei  Shanxi  InnerMongolia  Liaoning  Jilin  \
# 2001     77.4     60.4  251.5   184.2          115.8     205.5   89.1
# 2002     77.9     65.1  284.4   221.4          127.1     220.7   92.2
# 2003     82.0     66.2  328.6   251.7          149.3     236.7  134.3
# 2004     88.1     78.3  374.2   267.9          207.3     250.2  112.3
# 2005     92.1     89.0  459.1   290.0          240.5     279.6  143.4
# 2006     96.7     95.5  486.7   320.1          290.7     317.9  158.9
# 2007    102.9    103.4  529.0   344.9          340.0     362.2  170.5
# 2008     99.2    110.2  554.4   370.9          411.4     371.4  179.4
# 2009    100.4    122.3  577.8   375.4          445.3     406.9  185.7
# 2010    103.0    136.6  647.0   406.5          477.4     446.3  202.1
# 2011     94.4    152.0  724.6   438.8          598.2     455.1  233.9
# 2012     97.2    158.0  714.5   466.0          621.6     461.0  229.5
# ...

# %%
CO2_per_capita=CO2/population
CO2_per_capita
# Out:
#        Beijing   Tianjin     Hebei    Shanxi  InnerMongolia  Liaoning  \
# 2001  0.055884  0.060159  0.037543  0.056296       0.048635  0.048999
# 2002  0.054743  0.064647  0.042227  0.067213       0.053314  0.052510
# 2003  0.056319  0.065480  0.048545  0.075951       0.062573  0.056223
# 2004  0.059009  0.076465  0.054957  0.080330       0.086628  0.059331
# 2005  0.059883  0.085331  0.067012  0.086438       0.100083  0.066240
# 2006  0.060400  0.088837  0.070557  0.094844       0.120373  0.074432
# 2007  0.061396  0.092735  0.076192  0.101650       0.139975  0.084272
# 2008  0.056014  0.093707  0.079325  0.108736       0.168331  0.086072
# 2009  0.053978  0.099593  0.082144  0.109542       0.181164  0.093734
# 2010  0.052497  0.105158  0.089936  0.113738       0.193123  0.102011
# 2011  0.046756  0.112177  0.100069  0.122126       0.241015  0.103833
# 2012  0.046979  0.111819  0.098038  0.129050       0.249639  0.105035
# ...

# %%
# group data into east, middle, west 
CO2_grouped=pd.DataFrame()
CO2_grouped['West']=CO2.loc[:,CO2.columns.isin(a['West'])].sum(axis=1)
CO2_grouped['Middle']=CO2.loc[:,CO2.columns.isin(a['Middle'])].sum(axis=1)
CO2_grouped['East']=CO2.loc[:,CO2.columns.isin(a['East'])].sum(axis=1)

population_grouped=pd.DataFrame()
population_grouped['West']=population.loc[:,population.columns.isin(a['West'])].sum(axis=1)
population_grouped['Middle']=population.loc[:,population.columns.isin(a['Middle'])].sum(axis=1)
population_grouped['East']=population.loc[:,population.columns.isin(a['East'])].sum(axis=1)

CO2_per_capita_grouped=CO2_grouped/population_grouped
CO2_per_capita_grouped
# Out:
#           West    Middle      East
# 2001  0.018123  0.023422  0.030018
# 2002  0.020263  0.024906  0.032552
# 2003  0.025556  0.029464  0.037081
# 2004  0.027748  0.031740  0.042775
# 2005  0.031833  0.037103  0.051578
# 2006  0.035485  0.041869  0.055687
# 2007  0.038620  0.046049  0.060298
# 2008  0.041707  0.048043  0.061711
# 2009  0.046050  0.050343  0.064051
# 2010  0.051271  0.054903  0.068686
# 2011  0.056950  0.060957  0.073630
# 2012  0.061593  0.061558  0.074014
# 2013  0.062921  0.060277  0.074074
# 2014  0.064387  0.061512  0.074011
# 2015  0.063772  0.060162  0.074359

# %%
CO2_per_capita_grouped
CO2_per_capita_grouped_order=pd.DataFrame()
CO2_per_capita_grouped_order['East']=CO2_per_capita_grouped['East']
CO2_per_capita_grouped_order['Middle']=CO2_per_capita_grouped['Middle']
CO2_per_capita_grouped_order['West']=CO2_per_capita_grouped['West']
CO2_per_capita_grouped_order.index=[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]

# %%
#CO2_per_capita_grouped.plot(title='CO2 Emission per capita',figsize=(12,5))
plt.rcParams['figure.dpi'] = 200

fig,ax = plt.subplots()
CO2_per_capita_grouped_order.plot(ax=ax,figsize=(7,5))
ax.set_title('CO2 Emission per capita',fontsize=20)
# Out:
# Text(0.5,1,'CO2 Emission per capita')

# %%
national_CO2_emission=CO2.T.sum()
national_CO2_emission_per_capita=national_CO2_emission/population_national

fig,ax = plt.subplots()
national_CO2_emission_per_capita.plot(ax=ax,figsize=(7,5),kind='bar',color='blue')
ax.set_title('CO2 Emission per capita in China: 2001-2015',fontsize=20)
ax.set_xticklabels(labels = national_CO2_emission_per_capita.index,rotation =45)
# Out:
# [Text(0,0,'2001'),
#  Text(0,0,'2002'),
#  Text(0,0,'2003'),
#  Text(0,0,'2004'),
#  Text(0,0,'2005'),
#  Text(0,0,'2006'),
#  Text(0,0,'2007'),
#  Text(0,0,'2008'),
#  Text(0,0,'2009'),
#  Text(0,0,'2010'),
#  Text(0,0,'2011'),
#  Text(0,0,'2012'),
#  Text(0,0,'2013'),
#  Text(0,0,'2014'),
#  Text(0,0,'2015')]

# %% [markdown]
# # The trend of CO2 emission growth in province group 2001-2015

# %%
CO2_grouped_growth=pd.DataFrame()
CO2_grouped_growth['2002g']=CO2_grouped.T[2002]/CO2_grouped.T[2001]-1
CO2_grouped_growth['2003g']=CO2_grouped.T[2003]/CO2_grouped.T[2002]-1
CO2_grouped_growth['2004g']=CO2_grouped.T[2004]/CO2_grouped.T[2003]-1
CO2_grouped_growth['2005g']=CO2_grouped.T[2005]/CO2_grouped.T[2004]-1
CO2_grouped_growth['2006g']=CO2_grouped.T[2006]/CO2_grouped.T[2005]-1
CO2_grouped_growth['2007g']=CO2_grouped.T[2007]/CO2_grouped.T[2006]-1
CO2_grouped_growth['2008g']=CO2_grouped.T[2008]/CO2_grouped.T[2007]-1
CO2_grouped_growth['2009g']=CO2_grouped.T[2009]/CO2_grouped.T[2008]-1
CO2_grouped_growth['2010g']=CO2_grouped.T[2010]/CO2_grouped.T[2009]-1
CO2_grouped_growth['2011g']=CO2_grouped.T[2011]/CO2_grouped.T[2010]-1
CO2_grouped_growth['2012g']=CO2_grouped.T[2012]/CO2_grouped.T[2011]-1
CO2_grouped_growth['2013g']=CO2_grouped.T[2013]/CO2_grouped.T[2012]-1
CO2_grouped_growth['2014g']=CO2_grouped.T[2014]/CO2_grouped.T[2013]-1
CO2_grouped_growth['2015g']=CO2_grouped.T[2015]/CO2_grouped.T[2014]-1
CO2_grouped_growth=CO2_grouped_growth.T

# %%
CO2_grouped_growth
CO2_grouped_growth_order=pd.DataFrame()
CO2_grouped_growth_order['East']=CO2_grouped_growth['East']
CO2_grouped_growth_order['Middle']=CO2_grouped_growth['Middle']
CO2_grouped_growth_order['West']=CO2_grouped_growth['West']
CO2_grouped_growth_order.index=[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
CO2_grouped_growth_order
# Out:
#           East    Middle      West
# 2002  0.093429  0.068175  0.121918
# 2003  0.149559  0.188037  0.269667
# 2004  0.165493  0.082872  0.086962
# 2005  0.211387  0.148387  0.149646
# 2006  0.095565  0.130053  0.115655
# 2007  0.098113  0.101143  0.088490
# 2008  0.037008  0.047743  0.083198
# 2009  0.051533  0.051461  0.107480
# 2010  0.088872  0.093363  0.109954
# 2011  0.079910  0.112834  0.114835
# 2012  0.012589  0.013124  0.087394
# 2013  0.007343 -0.017119  0.027201
# 2014  0.005495  0.024688  0.028720
# 2015  0.010974 -0.017226 -0.001433

# %%
import numpy as np
fig,ax = plt.subplots()
CO2_grouped_growth_order.plot(ax=ax,figsize=(7,5))
ax.set_title('CO2 Emission Growth Rate',fontsize=20)
#year=[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
#ax.set_xticklabels(labels = np.array(year),rotation =45)
plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# # CO2 emission in sector categories

# %%
#A:Agriculture Animal Husbandry and Fishery (no data)
#B:mining
#C:manufacturing
#D:Production and Supply of power, water, gas
#E:construction
#F:service
#G:others
category={'A':['Logging and Transport of Wood and Bamboo                 '],
   'B':['Coal Mining and Dressing                                 ',
        'Petroleum and Natural Gas Extraction                     ',
        'Ferrous Metals Mining and Dressing                       ',
        'Nonferrous Metals Mining and Dressing                    ',
        'Nonmetal Minerals Mining and Dressing                    ',
        'Other Minerals Mining and Dressing                       '],
    'C':['Food Processing                                          ',
       'Food Production                                          ',
       'Beverage Production',
       'Tobacco Processing                                       ',
       'Textile Industry                                         ',
       'Garments and Other Fiber Products                        ',
       'Leather, Furs, Down and Related Products                 ',
       'Timber Processing, Bamboo, Cane, Palm Fiber & Straw Products',
       'Furniture Manufacturing                                  ',
       'Papermaking and Paper Products                           ',
       'Printing and Record Medium Reproduction                  ',
       'Cultural, Educational and Sports Articles                ',
       'Petroleum Processing and Coking                          ',
       'Raw Chemical Materials and Chemical Products             ',
       'Medical and Pharmaceutical Products                      ',
       'Chemical Fiber                                           ',
       'Rubber Products                                          ',
       'Plastic Products                                         ',
       'Nonmetal Mineral Products                                ',
       'Smelting and Pressing of Ferrous Metals                  ',
       'Smelting and Pressing of Nonferrous Metals               ',
       'Metal Products                                           ',
       'Ordinary Machinery                                       ',
       'Equipment for Special Purposes                           ',
       'Transportation Equipment                                 ',
       'Electric Equipment and Machinery                         ',
       'Electronic and Telecommunications Equipment              ',
       'Instruments, Meters, Cultural and Office Machinery         ',
       'Other Manufacturing Industry                             ',
       'Scrap and waste'],
    'D':['Production and Supply of Electric Power, Steam and Hot Water   ',
       'Production and Supply of Gas                             ',
       'Production and Supply of Tap Water                       '],
    'E':['Construction                                             '],
    'F':['Transportation, Storage, Post and Telecommunication Services    ',
       'Wholesale, Retail Trade and Catering Services            ',
        'Farming, Forestry, Animal Husbandry, Fishery and Water Conservancy      '],
    'G':['Others                                                   ', 
         'Urban',
         'Rural']
  }

# %%
CO2_sector=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National sectoral CO2 emissions 00-15.xlsx',sheet_name='Sum by sector')
CO2_sector=CO2_sector.drop([2000],axis=1)
CO2_sector
# Out:
#                                                       2001    2002    2003  \
# Total Consumption                                   3250.1  3472.1  4085.6
# Farming, Forestry, Animal Husbandry, Fishery an...    46.6    51.3    58.8
# Coal Mining and Dressing                       ...    46.5    46.9    64.6
# Petroleum and Natural Gas Extraction           ...    42.8    41.7    29.4
# Ferrous Metals Mining and Dressing             ...     3.4     3.9     4.3
# Nonferrous Metals Mining and Dressing          ...     2.7     3.0     3.0
# Nonmetal Minerals Mining and Dressing          ...     7.7     7.9     8.1
# Other Minerals Mining and Dressing             ...     2.6     2.4    21.9
# Logging and Transport of Wood and Bamboo       ...     0.0     0.0     0.0
# Food Processing                                ...    20.8    22.0    26.7
# Food Production                                ...    13.5    13.1    11.9
# ...

# %%
CO2_categorized=pd.DataFrame()
CO2_categorized['Agriculture Animal Husbandry and Fishery']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['A'])].sum(axis=1)
CO2_categorized['Mining']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['B'])].sum(axis=1)
CO2_categorized['Manufacturing']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['C'])].sum(axis=1)
CO2_categorized['Production and Supply of Power, Water, Gas']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['D'])].sum(axis=1)
CO2_categorized['Construction']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['E'])].sum(axis=1)
CO2_categorized['Service']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['F'])].sum(axis=1)
CO2_categorized['Others']=CO2_sector.T.loc[:,CO2_sector.T.columns.isin(category['G'])].sum(axis=1)
CO2_categorized
# Out:
#       Agriculture Animal Husbandry and Fishery  Mining  Manufacturing  \
# 2001                                       0.0   105.7         1222.9
# 2002                                       0.0   105.8         1298.9
# 2003                                       0.0   131.3         1531.1
# 2004                                       0.0    84.0         1901.2
# 2005                                       0.0   115.1         2271.0
# 2006                                       0.0   129.5         2507.0
# 2007                                       0.0   142.4         2809.7
# 2008                                       0.0   149.3         2929.0
# 2009                                       0.0   186.7         3228.2
# 2010                                       0.0   206.6         3399.7
# 2011                                       0.0   201.4         3716.9
# 2012                                       0.0   208.9         3741.3
# ...

# %%
#CO2_categorized['Total']=CO2_categorized['A']+CO2_categorized['B']+CO2_categorized['C']+CO2_categorized['D']+CO2_categorized['E']+CO2_categorized['F']+CO2_categorized['G']
fig,ax = plt.subplots()
CO2_categorized.iloc[:,1:6].plot(ax=ax,figsize=(12,5))
ax.set_title('CO2 Emission in Sector Categories',fontsize=20)
# Out:
# Text(0.5,1,'CO2 Emission in Sector Categories')

# %% [markdown]
# # CO2 emission by types of fossile fuel

# %%
CO2_energy=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National sectoral CO2 emissions 00-15.xlsx',
                 sheet_name='Sum by energy')
CO2_energy=CO2_energy.drop(2000,axis=0)

# %%
CO2_energy_sorted=CO2_energy.sort_values(by=[2015],axis=1,ascending=False)
fig, ax = plt.subplots()
CO2_energy_sorted.iloc[:,1:5].plot(ax=ax,figsize=(12,5))
ax.set_title('Carbon Emission of Different Types of fossile fule')
# Out:
# Text(0.5,1,'carbon emission of different types of fossile fule')

# %%
CO2_energy_sorted
# Out:
#        Total  Raw Coal    Coke  Process  Diesel Oil  Other Gas  Gasoline  \
# 2001  3250.1    1868.2   325.6    192.1       220.7      128.4     104.8
# 2002  3472.1    2049.3   350.1    210.7       240.2       92.9     110.8
# 2003  4085.6    2433.9   435.2    250.5       264.5       94.4     122.3
# 2004  4680.4    2772.3   493.9    281.0       314.9      113.4     137.0
# 2005  5401.1    3151.1   687.3    310.6       339.1      160.3     141.8
# 2006  6008.7    3488.1   763.4    359.4       373.2      196.6     158.3
# 2007  6546.3    3752.1   852.7    395.6       385.7      275.9     161.2
# 2008  6761.0    3872.2   875.6    406.8       418.2      261.8     179.5
# 2009  7333.7    4163.5   992.2    477.7       418.6      310.7     180.3
# 2010  7904.5    4407.8  1071.6    546.9       454.0      337.5     203.2
# 2011  8741.6    4917.7  1169.1    610.0       483.0      401.2     222.1
# 2012  9080.5    5076.8  1242.0    634.7       523.4      396.3     238.8
# ...

# %%
# proportion of CO2 emission in 2001
prop2001=CO2_energy_sorted.iloc[0,1:]/float(CO2_energy_sorted.iloc[0,0:1])

# %%
prop2001_clear=prop2001[0:9]
prop2001_clear['Other']=prop2001[9:].sum()
fig, ax = plt.subplots()
prop2001_clear.plot(kind='pie',figsize=(5,5))
ax.set_title('Carbon Emission Proportion in 2001')
# Out:
# Text(0.5,1,'Carbon Emission Proportion in 2001')

# %%
# proportion of CO2 emission in 2015 
prop2015=CO2_energy_sorted.iloc[-1,1:]/float(CO2_energy_sorted.iloc[-1,0:1])

# %%
prop2015_clear=prop2015[0:9]
prop2015_clear['Other']=prop2015[9:].sum()
fig, ax = plt.subplots()
prop2015_clear.plot(kind='pie',figsize=(5,5))
ax.set_title('Carbon Emission Proportion in 2015')
# Out:
# Text(0.5,1,'Carbon Emission Proportion in 2015')

# %% [markdown]
# # energy efficiency and sectors

# %%
sector_CO2_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National sectoral CO2 emissions 00-15 no space.xlsx',
                            sheet_name='Sum by sector')
sector_CO2_total=sector_CO2_total.drop([2000],axis=1)
sector_CO2_total=sector_CO2_total.iloc[1:45,:]
sector_CO2_total
# Out:
#                                                       2001    2002    2003  \
# Farming, Forestry, Animal Husbandry, Fishery & ...    46.6    51.3    58.8
# Coal Mining and Dressing                              46.5    46.9    64.6
# Petroleum and Naturl Gas Extraction                   42.8    41.7    29.4
# Ferrous Metals Mining and Dressing                     3.4     3.9     4.3
# Nonferrous Metals Mining and Dressing                  2.7     3.0     3.0
# Nonmetal Minerals Mining and Dressing                  7.7     7.9     8.1
# Other Minerals Mining and Dressing                     2.6     2.4    21.9
# Logging and Transport of Wood and Bamboo               0.0     0.0     0.0
# Food Processing                                       20.8    22.0    26.7
# Food Production                                       13.5    13.1    11.9
# Beverage Production                                   11.6    11.7    11.5
# ...

# %%
# sum of energy consumption in sectors 2001-2015
sector_energy_2015_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2015')
sector_energy_2015_total=sector_energy_2015_total.iloc[1:46,:]
sector_energy_2015_total=sector_energy_2015_total.sum(axis=1)
sector_energy_2014_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2014')
sector_energy_2014_total=sector_energy_2014_total.iloc[1:46,:]
sector_energy_2014_total=sector_energy_2014_total.sum(axis=1)
sector_energy_2013_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2013')
sector_energy_2013_total=sector_energy_2013_total.iloc[1:46,:]
sector_energy_2013_total=sector_energy_2013_total.sum(axis=1)
sector_energy_2012_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2012')
sector_energy_2012_total=sector_energy_2012_total.iloc[1:46,:]
sector_energy_2012_total=sector_energy_2012_total.sum(axis=1)
sector_energy_2011_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2011')
sector_energy_2011_total=sector_energy_2011_total.iloc[1:46,:]
sector_energy_2011_total=sector_energy_2011_total.sum(axis=1)
sector_energy_2010_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2010')
sector_energy_2010_total=sector_energy_2010_total.iloc[1:46,:]
sector_energy_2010_total=sector_energy_2010_total.sum(axis=1)
sector_energy_2009_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2009')
sector_energy_2009_total=sector_energy_2009_total.iloc[1:46,:]
sector_energy_2009_total=sector_energy_2009_total.sum(axis=1)
sector_energy_2008_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2008')
sector_energy_2008_total=sector_energy_2008_total.iloc[1:46,:]
sector_energy_2008_total=sector_energy_2008_total.sum(axis=1)
sector_energy_2007_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2007')
sector_energy_2007_total=sector_energy_2007_total.iloc[1:46,:]
sector_energy_2007_total=sector_energy_2007_total.sum(axis=1)
sector_energy_2006_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2006')
sector_energy_2006_total=sector_energy_2006_total.iloc[1:46,:]
sector_energy_2006_total=sector_energy_2006_total.sum(axis=1)
sector_energy_2005_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2005')
sector_energy_2005_total=sector_energy_2005_total.iloc[1:46,:]
sector_energy_2005_total=sector_energy_2005_total.sum(axis=1)
sector_energy_2004_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2004')
sector_energy_2004_total=sector_energy_2004_total.iloc[1:46,:]
sector_energy_2004_total=sector_energy_2004_total.sum(axis=1)
sector_energy_2003_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2003')
sector_energy_2003_total=sector_energy_2003_total.iloc[1:46,:]
sector_energy_2003_total=sector_energy_2003_total.sum(axis=1)
sector_energy_2002_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2002')
sector_energy_2002_total=sector_energy_2002_total.iloc[1:46,:]
sector_energy_2002_total=sector_energy_2002_total.sum(axis=1)
sector_energy_2001_total=pd.read_excel('/Users/Kaye/Desktop/Data_Bootcamp/Project/National energy inventory 00-15.xlsx',
                            sheet_name='2001')
sector_energy_2001_total=sector_energy_2001_total.iloc[1:46,:]
sector_energy_2001_total=sector_energy_2001_total.sum(axis=1)

# %%
sector_energy_total=pd.DataFrame()
sector_energy_total[2001]=sector_energy_2001_total
sector_energy_total[2002]=sector_energy_2002_total
sector_energy_total[2003]=sector_energy_2003_total
sector_energy_total[2004]=sector_energy_2004_total
sector_energy_total[2005]=sector_energy_2005_total
sector_energy_total[2006]=sector_energy_2006_total
sector_energy_total[2007]=sector_energy_2007_total
sector_energy_total[2008]=sector_energy_2008_total
sector_energy_total[2009]=sector_energy_2009_total
sector_energy_total[2010]=sector_energy_2010_total
sector_energy_total[2011]=sector_energy_2011_total
sector_energy_total[2012]=sector_energy_2012_total
sector_energy_total[2013]=sector_energy_2013_total
sector_energy_total[2014]=sector_energy_2014_total
sector_energy_total[2015]=sector_energy_2015_total

# %%
sector_energy_total=sector_energy_total.drop('Total Final Consumption')

# %%
sector_energy_total
# Out:
#                                                        2001     2002     2003  \
# Farming, Forestry, Animal Husbandry, Fishery & ...   2899.9   3173.2   3647.4
# Coal Mining and Dressing                             4414.2   3937.7   4404.9
# Petroleum and Naturl Gas Extraction                  6450.8   6202.6   6314.7
# Ferrous Metals Mining and Dressing                    222.7    263.1    278.3
# Nonferrous Metals Mining and Dressing                 233.7    247.3    238.7
# Nonmetal Minerals Mining and Dressing                1726.2   1806.3   1692.6
# Other Minerals Mining and Dressing                    338.3    274.4    460.6
# Logging and Transport of Wood and Bamboo                0.0      0.0      0.0
# Food Processing                                      3369.2   3565.3   3293.9
# Food Production                                      2940.4   3168.6   2817.4
# Beverage Production                                  1893.4   1851.8   2037.7
# ...

# %%
category_energy={'A':['Logging and Transport of Wood and Bamboo'],
   'B':['Coal Mining and Dressing',
        'Petroleum and Naturl Gas Extraction',
        'Ferrous Metals Mining and Dressing',
       'Nonferrous Metals Mining and Dressing',
       'Nonmetal Minerals Mining and Dressing',
       'Other Minerals Mining and Dressing'],
    'C':['Food Production', 'Beverage Production', 'Tobacco Processing',
       'Textile Industry', 'Garments and Other Fiber Products',
       'Leather, Furs, Down and Related Products',
       'Timber Processing, Bamboo, Cane, Palm & Straw Products',
       'Furniture Manufacturing', 'Papermaking and Paper Products',
       'Printing and Record Medium Reproduction',
       'Cultural, Educational and Sports Articles',
       'Petroleum Processing and Coking',
       'Raw Chemical Materials and Chemical Products',
       'Medical and Pharmaceutical Products', 'Chemical Fiber',
       'Rubber Products', 'Plastic Products', 'Nonmetal Mineral Products',
       'Smelting and Pressing of Ferrous Metals',
       'Smelting and Pressing of Nonferrous Metals               ',
       'Smelting and Pressing of Nonferrous Metals', 'Metal Products',
       'Ordinary Machinery', 'Equipment for Special Purpose',
       'Transportation Equipment', 'Electric Equipment and Machinery',
       'Electronic and Telecommunications Equipment',
       'Instruments, Meters Cultural and Office Machinery',
       'Other Manufacturing Industry', 'Scrap and waste'],
    'D':['Electric Power, Steam and Hot Water Production and Supply',
       'Gas Production and Supply', 'Tap Water Production and Supply'],
    'E':['Construction'],
    'F':['Transport, Storage, Postal & Telecommunications Services',
       'Wholesale, Retail Trade and Catering Service',
        'Farming, Forestry, Animal Husbandry, Fishery & Water Conservancy'],
    'G':['Others                                                   ', 
         'Urban',
         'Rural']
  }

# %%
sector_energy_categorized=pd.DataFrame()
sector_energy_categorized['A']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['A'])].sum(axis=1)
sector_energy_categorized['B']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['B'])].sum(axis=1)
sector_energy_categorized['C']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['C'])].sum(axis=1)
sector_energy_categorized['D']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['D'])].sum(axis=1)
sector_energy_categorized['E']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['E'])].sum(axis=1)
sector_energy_categorized['F']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['F'])].sum(axis=1)
sector_energy_categorized['G']=sector_energy_total.T.loc[:,sector_energy_total.T.columns.isin(category_energy['G'])].sum(axis=1)
sector_energy_categorized
# Out:
#         A        B         C        D       E        F    G
# 2001  0.0  13385.9  166595.6  11409.8  1778.5  15015.2  0.0
# 2002  0.0  12731.4  177617.8  12161.8  1925.6  16521.8  0.0
# 2003  0.0  13389.8  194276.8  13939.2  2142.9  18914.2  0.0
# 2004  0.0  11764.2  219343.1  13997.3  2613.2  22645.6  0.0
# 2005  0.0  12830.3  258833.4  13990.5  2837.9  24052.6  0.0
# 2006  0.0  13256.9  278435.5  16337.7  3102.0  26718.6  0.0
# 2007  0.0  13168.1  305067.7  12196.7  3403.0  28378.2  0.0
# 2008  0.0  13052.2  307120.8  11362.9  3036.3  29785.6  0.0
# 2009  0.0  15229.6  323343.3  11558.1  3795.7  30081.3  0.0
# 2010  0.0  17315.3  363375.2  14353.0  4391.7  32761.7  0.0
# 2011  0.0  18875.6  390688.8  13847.5  4607.4  35778.2  0.0
# 2012  0.0  20388.3  405198.3  14036.9  4842.3  38906.4  0.0
# 2013  0.0  20436.8  423583.4  13758.2  5400.3  41355.9  0.0
# 2014  0.0  18478.8  432827.7  12955.5  5807.9  42962.2  0.0
# 2015  0.0  15915.0  441248.7  14231.1  6032.6  45260.6  0.0

# %%
fig, ax = plt.subplots()
sector_energy_categorized.iloc[:,1:6].plot(ax=ax, figsize=(12,5))
ax.set_title('Setoral energy consumption', loc='left',fontsize=25)
plt.rcParams['figure.dpi'] = 200
ax.legend(loc='best')

# %%
energy_CO2_efficiency=sector_CO2_total/sector_energy_total
energy_CO2_efficiency
# Out:
#                                                         2001      2002  \
# Farming, Forestry, Animal Husbandry, Fishery & ...  0.016070  0.016167
# Coal Mining and Dressing                            0.010534  0.011911
# Petroleum and Naturl Gas Extraction                 0.006635  0.006723
# Ferrous Metals Mining and Dressing                  0.015267  0.014823
# Nonferrous Metals Mining and Dressing               0.011553  0.012131
# Nonmetal Minerals Mining and Dressing               0.004461  0.004374
# Other Minerals Mining and Dressing                  0.007685  0.008746
# Logging and Transport of Wood and Bamboo                 NaN       NaN
# Food Processing                                     0.006174  0.006171
# Food Production                                     0.004591  0.004134
# Beverage Production                                 0.006127  0.006318
# Tobacco Processing                                  0.008111  0.009829
# ...

# %%
fig, ax = plt.subplots()
energy_CO2_efficiency.T.sort_values(by=[2015],ascending=False,axis=1).iloc[:,:10].plot(ax=ax, figsize=(12,5))
ax.set_title('energy_CO2_efficiency', loc='left',fontsize=25)
plt.rcParams['figure.dpi'] = 200
ax.legend(loc='best')

# %% [markdown]
# # when taking into consideration the unit
